# %% [markdown]
# <a href="https://colab.research.google.com/github/wizardMati/expotraintelos/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

movies = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/zad/tmdb_movies.csv"
)
genres = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/zad/tmdb_genres.csv"
)
q3 = movies["vote_count"].quantile(0.75)

top_10_movies = (
    movies[movies["vote_count"] > q3]
    .sort_values("vote_average", ascending=False)
    .head(10)
)

print("\nTOP 10 najwyżej ocenianych filmów:")
print(top_10_movies[["title", "vote_average", "vote_count"]])

movies["release_date"] = pd.to_datetime(movies["release_date"], errors="coerce")
movies["year"] = movies["release_date"].dt.year

movies_2010_2016 = movies[(movies["year"] >= 2010) & (movies["year"] <= 2016)]

yearly_stats = (
    movies_2010_2016
    .groupby("year")[["revenue", "budget"]]
    .mean()
    .reset_index()
)

plt.figure(figsize=(10, 6))
plt.bar(yearly_stats["year"], yearly_stats["revenue"], label="Średni przychód")
plt.plot(
    yearly_stats["year"],
    yearly_stats["budget"],
    marker="o",
    label="Średni budżet"
)

plt.xlabel("Rok")
plt.ylabel("Kwota (USD)")
plt.title("Średni przychód i budżet filmów (2010–2016)")

plt.ticklabel_format(style="plain", axis="y")

plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

movies_genres = movies.merge(
    genres,
    left_on="genre_id",
    right_on="id",
    how="left"
)

genre_counts = movies_genres["name"].value_counts()

most_common_genre = genre_counts.idxmax()
most_common_count = genre_counts.max()

print("\nNajczęściej występujący gatunek:")
print(f"Gatunek: {most_common_genre}")
print(f"Liczba filmów: {most_common_count}")

avg_runtime_by_genre = (
    movies_genres
    .groupby("name")["runtime"]
    .mean()
    .sort_values(ascending=False)
)

longest_runtime_genre = avg_runtime_by_genre.idxmax()
longest_runtime_value = avg_runtime_by_genre.max()

print("\nGatunek o najdłuższym średnim czasie trwania:")
print(f"Gatunek: {longest_runtime_genre}")
print(f"Średni czas trwania: {longest_runtime_value:.2f} min")
runtime_data = movies_genres[
    movies_genres["name"] == longest_runtime_genre
]["runtime"]

plt.figure(figsize=(8, 5))
plt.hist(runtime_data, bins=20)
plt.title(f"Histogram czasu trwania filmów – {longest_runtime_genre}")
plt.xlabel("Czas trwania (minuty)")
plt.ylabel("Liczba filmów")
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# TOP 10 najwyżej ocenianych filmów:
#                                 title  vote_average  vote_count
# 1881         The Shawshank Redemption           8.5        8205
# 3337                    The Godfather           8.4        5893
# 2731           The Godfather: Part II           8.3        3338
# 3232                     Pulp Fiction           8.3        8428
# 3865                         Whiplash           8.3        4254
# 1818                 Schindler's List           8.3        4329
# 662                        Fight Club           8.3        9413
# 2294                    Spirited Away           8.3        3840
# 2170                           Psycho           8.2        2320
# 3719  One Flew Over the Cuckoo's Nest           8.2        2919
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1167623715.py in <cell line: 0>()
#      52 plt.show()
#      53
# ---> 54 movies_genres = movies.merge(
#      55     genres,
#      56     left_on="genre_id",
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'id'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1533269052.py in <cell line: 0>()
#       3 os.listdir("/content/drive/MyDrive")
#       4 os.listdir("/content/drive/MyDrive/Colab Notebooks")
# ----> 5 os.listdir("/content/drive/MyDrive/Colab Notebooks/Zda")
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/Zda'

# %%
# !git config --global user.name "wizardMati"
# !git config --global user.email "mateo.monikowski@gmail.com"

# %%
# !git clone https://github.com/wizardMati/matplotlip
# Out:
# Cloning into 'matplotlip'...
# warning: You appear to have cloned an empty repository.

# %%
import shutil

shutil.copy("/content/baza_filmow.ipynb", "/content/baza-filmow/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3152851000.py in <cell line: 0>()
#       1 import shutil
#       2
# ----> 3 shutil.copy("/content/baza_filmow.ipynb", "/content/baza-filmow/")
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
#     262                 with open(dst, 'wb') as fdst:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/baza_filmow.ipynb'
